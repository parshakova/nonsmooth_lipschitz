# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils import *
sns.set()

# %%
p = np.array([1, 1])
q = np.array([1, -1])

# %%
w0 = np.array([1 + np.log(2), 1 - np.log(2)])

beta = 0.9
a = (1-beta) / (1+beta)
c = a / 2

c = 0.1

# %%
xlim = (-1000, 1000)
ylim = (-1000, 1000)
countex_level_sets(c, xlim, ylim, filename=f"counterexample_c{c:.2f}", 
                   figsize=(6, 4), show_ticks=False)
