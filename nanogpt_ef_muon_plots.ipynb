# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils import *


plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = 12
plt.rcParams["axes.linewidth"] = 1.5
plt.rcParams["text.latex.preamble"] = r"\usepackage{amsmath}"
plt.rc("text", usetex=True)
plt.rc("legend", fontsize=10)

# %%
# Load data
df_vanilla_muon = pd.read_csv("data/vanilla_muon_data.csv")
df_muon = pd.read_csv("data/muonmax_sweep_data.csv")
df_efmuon = pd.read_csv("data/efmuonmax_sweep_data.csv")
df_muon_nadam = pd.read_csv("data/muonmax_nadam_sweep_data.csv")
df_efmuon_nadam = pd.read_csv("data/efmuonmax_nadam_sweep_data.csv")

for df in [df_muon, df_efmuon, df_muon_nadam, df_efmuon_nadam]:
    df["config"] = df["base_lr"].astype(str) + "_" + df["lr_multiplier"].astype(str)

df_vanilla_muon["config"] = df_vanilla_muon["trial_id"].astype(str) 

# best_muon = get_best_trial(df_muon, "MuonMax")
# best_efmuon = get_best_trial(df_efmuon, "EF-MuonMax")
best_muon_nadam = get_best_trial(df_muon_nadam, "Muon")
best_efmuon_nadam = get_best_trial(df_efmuon_nadam, "EF-Muon")
best_vanilla_muon = get_best_trial(df_vanilla_muon, "Vanilla Muon")

trials = [
    # ("MuonMax", best_muon),
    # ("EF-MuonMax", best_efmuon),
    ("MuonMax", best_muon_nadam),
    ("EF-MuonMax", best_efmuon_nadam),
    ("Vanilla Muon", best_vanilla_muon),
]
all_dfs = [
    # ("MuonMax", df_muon),
    # ("EF-MuonMax", df_efmuon),
    ("MuonMax", df_muon_nadam),
    ("EF-MuonMax", df_efmuon_nadam),
    # ("Vanilla Muon", df_vanilla_muon),
]
# Out:
# Muon: best config = 0.01_30.0, final valid loss = 3.2697
# EF-Muon: best config = 0.01_30.0, final valid loss = 3.4295
# Vanilla Muon: best config = 3, final valid loss = 3.0107

# %%
df_muon
# Out:
#        trial_id  global_step  base_lr  lr_multiplier  beta  nesterov  \
# 0             1          100   0.0001            0.1  0.95     False
# 1             1          200   0.0001            0.1  0.95     False
# 2             1          300   0.0001            0.1  0.95     False
# 3             1          400   0.0001            0.1  0.95     False
# 4             1          500   0.0001            0.1  0.95     False
# ...         ...          ...      ...            ...   ...       ...
# 29995         9        99600   0.0005           30.0  0.95     False
# 29996         9        99700   0.0005           30.0  0.95     False
# 29997         9        99800   0.0005           30.0  0.95     False
# 29998         9        99900   0.0005           30.0  0.95     False
# 29999         9       100000   0.0005           30.0  0.95     False
#
#        weight_decay    s  epoch  eval_time  ...  train/num_examples  \
# 0             0.001  1.0    NaN        NaN  ...                 NaN
# 1             0.001  1.0    NaN        NaN  ...                 NaN
# 2             0.001  1.0    NaN        NaN  ...                 NaN
# 3             0.001  1.0    NaN        NaN  ...                 NaN
# 4             0.001  1.0    NaN        NaN  ...                 NaN
# ...             ...  ...    ...        ...  ...                 ...
# 29995         0.001  1.0    NaN        NaN  ...                 NaN
# 29996         0.001  1.0    NaN        NaN  ...                 NaN
# 29997         0.001  1.0    NaN        NaN  ...                 NaN
# 29998         0.001  1.0    NaN        NaN  ...                 NaN
# 29999         0.001  1.0    0.0  85.337409  ...          51183616.0
#
#        train/perplexity  train_cost  train_steps_per_sec   update_norm  \
# 0                   NaN   11.345487             1.092558           NaN
# 1                   NaN   11.345698             4.534532           NaN
# 2                   NaN   11.346089             4.534894           NaN
# 3                   NaN   11.346127             4.535240           NaN
# 4                   NaN   11.346127             4.535432           NaN
# ...                 ...         ...                  ...           ...
# 29995               NaN    5.803498             4.538389           NaN
# 29996               NaN    5.803561             4.537481           NaN
# 29997               NaN    5.803525             4.537466           NaN
# 29998               NaN    5.803557             4.537534           NaN
# 29999          347.7917    5.803537                  NaN  3.433297e-11
#
#        valid/ce_loss  valid/error_rate  valid/num_examples  valid/perplexity  \
# 0                NaN               NaN                 NaN               NaN
# 1                NaN               NaN                 NaN               NaN
# 2                NaN               NaN                 NaN               NaN
# 3                NaN               NaN                 NaN               NaN
# 4                NaN               NaN                 NaN               NaN
# ...              ...               ...                 ...               ...
# 29995            NaN               NaN                 NaN               NaN
# 29996            NaN               NaN                 NaN               NaN
# 29997            NaN               NaN                 NaN               NaN
# 29998            NaN               NaN                 NaN               NaN
# 29999       5.846872          0.645805          51183616.0         346.14972
#
#             config
# 0       0.0001_0.1
# 1       0.0001_0.1
# 2       0.0001_0.1
# 3       0.0001_0.1
# 4       0.0001_0.1
# ...            ...
# 29995  0.0005_30.0
# 29996  0.0005_30.0
# 29997  0.0005_30.0
# 29998  0.0005_30.0
# 29999  0.0005_30.0
#
# [30000 rows x 30 columns]

# %%
# Train CE loss vs. step (sparse evals)
plot_loss_vs_step(trials, "train/ce_loss", "Train CE Loss",
                  filename="best_train_ce_loss", sparse=True)

# %%
# Validation loss vs. step (sparse evals)
plot_loss_vs_step(trials, "valid/ce_loss", "Validation CE Loss",
                  filename="best_valid_loss", sparse=True)

# %%
# Validation loss vs. effective LR (sensitivity plot)
plot_final_metric_vs_lr(all_dfs, "valid/ce_loss", "Final Validation CE Loss",
                        filename="valid_loss_vs_lr")

# %%
best_vanilla_muon['learning_rate'].iloc[0]
# Out:
# np.float64(0.0001357491896)
